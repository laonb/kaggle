# %%
PATH = 'data/mnist/'

# %%
import os
filelist = os.listdir(f'{PATH}/test')
fileid = [filename.split('.')[0] for filename in filelist]

# %%
fileid[:10]
# Out:
# ['9885',
#  '2701',
#  '16454',
#  '17137',
#  '16733',
#  '20677',
#  '18697',
#  '14175',
#  '11231',
#  '2964']
